# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajayrawati/Captcha_Detection/blob/main/captcha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import os
# from datetime import datetime
#
# from mltu.configs import BaseModelConfigs
#
#
# class ModelConfigs(BaseModelConfigs):
#     def __init__(self):
#         super().__init__()
#         self.model_path = os.path.join("Models/02_captcha_to_text", datetime.strftime(datetime.now(), "%Y%m%d%H%M"))
#         self.vocab = ""
#         self.height = 50
#         self.width = 200
#         self.max_text_length = 0
#         self.batch_size = 64
#         self.learning_rate = 1e-3
#         self.train_epochs = 20
#         self.train_workers = 20

# %%
import os
from datetime import datetime

from mltu.configs import BaseModelConfigs


class ModelConfigs(BaseModelConfigs):
    def __init__(self):
        super().__init__()
        self.model_path = os.path.join("Models/02_captcha_to_text", datetime.strftime(datetime.now(), "%Y%m%d%H%M"))
        self.vocab = ""
        self.height = 50
        self.width = 200
        self.max_text_length = 0
        self.batch_size = 64
        self.learning_rate = 1e-3
        self.train_epochs = 1000
        self.train_workers = 20

# %%
from keras import layers
from keras.models import Model

from mltu.tensorflow.model_utils import residual_block
from keras import layers

class NormalizeLayer(layers.Layer):
    def call(self, inputs):
        return inputs / 255.0

def train_model(input_dim, output_dim, activation="leaky_relu", dropout=0.2):
    inputs = layers.Input(shape=input_dim, name="input")

    # Replace Lambda layer with a custom NormalizeLayer
    normalized_input = NormalizeLayer()(inputs)

    x1 = residual_block(normalized_input, 16, activation=activation, skip_conv=True, strides=1, dropout=dropout)
    x2 = residual_block(x1, 16, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x3 = residual_block(x2, 16, activation=activation, skip_conv=False, strides=1, dropout=dropout)
    x4 = residual_block(x3, 32, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x5 = residual_block(x4, 32, activation=activation, skip_conv=False, strides=1, dropout=dropout)
    x6 = residual_block(x5, 64, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x7 = residual_block(x6, 32, activation=activation, skip_conv=True, strides=1, dropout=dropout)
    x8 = residual_block(x7, 64, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x9 = residual_block(x8, 64, activation=activation, skip_conv=False, strides=1, dropout=dropout)

    squeezed = layers.Reshape((x9.shape[-3] * x9.shape[-2], x9.shape[-1]))(x9)
    blstm = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(squeezed)
    blstm = layers.Dropout(dropout)(blstm)
    output = layers.Dense(output_dim + 1, activation="softmax", name="output")(blstm)

    model = Model(inputs=inputs, outputs=output)
    return model

# %%
import tensorflow as tf
try: [tf.config.experimental.set_memory_growth(gpu, True) for gpu in tf.config.experimental.list_physical_devices("GPU")]
except: pass

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

from mltu.tensorflow.dataProvider import DataProvider
from mltu.tensorflow.losses import CTCloss
from mltu.tensorflow.callbacks import Model2onnx, TrainLogger
from mltu.tensorflow.metrics import CWERMetric

from mltu.preprocessors import ImageReader
from mltu.transformers import ImageResizer, LabelIndexer, LabelPadding
from mltu.augmentors import RandomBrightness, RandomRotate, RandomErodeDilate
from mltu.annotations.images import CVImage



import os
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile


def download_and_unzip(url, extract_to="Datasets"):
    http_response = urlopen(url)
    zipfile = ZipFile(BytesIO(http_response.read()))
    zipfile.extractall(path=extract_to)


if not os.path.exists(os.path.join("Datasets", "captcha_images_v2")):
    download_and_unzip("",
                       extract_to="Datasets")

# Create a list of all the images and labels in the dataset
dataset, vocab, max_len = [], set(), 0
captcha_path = os.path.join("Datasets", "captcha_images_v2")
for file in os.listdir(captcha_path):
    file_path = os.path.join(captcha_path, file)
    label = os.path.splitext(file)[0] # Get the file name without the extension
    dataset.append([file_path, label])
    vocab.update(list(label))
    max_len = max(max_len, len(label))

configs = ModelConfigs()

# Save vocab and maximum text length to configs
configs.vocab = "".join(vocab)
configs.max_text_length = max_len
configs.save()

# Create a data provider for the dataset
data_provider = DataProvider(
    dataset=dataset,
    skip_validation=True,
    batch_size=configs.batch_size,
    data_preprocessors=[ImageReader(CVImage)],
    transformers=[
        ImageResizer(configs.width, configs.height),
        LabelIndexer(configs.vocab),
        LabelPadding(max_word_length=configs.max_text_length, padding_value=len(configs.vocab))
        ],
)
# Split the dataset into training and validation sets
train_data_provider, val_data_provider = data_provider.split(split = 0.9)

# Augment training data with random brightness, rotation and erode/dilate
train_data_provider.augmentors = [RandomBrightness(), RandomRotate(), RandomErodeDilate()]

# Creating TensorFlow model architecture
model = train_model(
    input_dim = (configs.height, configs.width, 3),
    output_dim = len(configs.vocab),
)

# Compile the model and print summary
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=configs.learning_rate),
    loss=CTCloss(),
    metrics=[CWERMetric(padding_token=len(configs.vocab))],
    run_eagerly=False
)

# Define path to save the model
os.makedirs(configs.model_path, exist_ok=True)

# Define callbacks
earlystopper = EarlyStopping(monitor="val_CER", patience=50, verbose=1, mode="min")
checkpoint = ModelCheckpoint(f"{configs.model_path}/model.keras", monitor="val_CER", verbose=1, save_best_only=True, mode="min")
trainLogger = TrainLogger(configs.model_path)
tb_callback = TensorBoard(f"{configs.model_path}/logs", update_freq=1)
reduceLROnPlat = ReduceLROnPlateau(monitor="val_CER", factor=0.9, min_delta=1e-10, patience=20, verbose=1, mode="min")

# Train the model
model.fit(
    train_data_provider,
    validation_data=val_data_provider,
    epochs=configs.train_epochs,
    callbacks=[earlystopper, checkpoint, trainLogger, reduceLROnPlat, tb_callback]
)
model.save('model.keras')
# Save training and validation datasets as csv files
train_data_provider.to_csv(os.path.join(configs.model_path, "train.csv"))
val_data_provider.to_csv(os.path.join(configs.model_path, "val.csv"))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/1000
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - CER: 3.8090 - WER: 1.0000 - loss: 82.7404
# Epoch 1: val_CER improved from inf to 2.03038, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 374ms/step - CER: 3.7050 - WER: 1.0000 - loss: 80.6381 - val_CER: 2.0304 - val_WER: 1.0000 - val_loss: 19.9176 - learning_rate: 0.0010
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - CER: 1.7151 - WER: 1.0000 - loss: 19.2691
# Epoch 2: val_CER improved from 2.03038 to 1.51519, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 218ms/step - CER: 1.7043 - WER: 1.0000 - loss: 19.1926 - val_CER: 1.5152 - val_WER: 1.0000 - val_loss: 19.0532 - learning_rate: 0.0010
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - CER: 1.4215 - WER: 1.0000 - loss: 16.8134
# Epoch 3: val_CER improved from 1.51519 to 1.34346, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - CER: 1.4174 - WER: 1.0000 - loss: 16.8002 - val_CER: 1.3435 - val_WER: 1.0000 - val_loss: 19.1197 - learning_rate: 0.0010
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - CER: 1.2988 - WER: 1.0000 - loss: 16.4269
# Epoch 4: val_CER improved from 1.34346 to 1.25760, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - CER: 1.2966 - WER: 1.0000 - loss: 16.4234 - val_CER: 1.2576 - val_WER: 1.0000 - val_loss: 16.8177 - learning_rate: 0.0010
# Epoch 5/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - CER: 1.2310 - WER: 1.0000 - loss: 16.3600
# Epoch 5: val_CER improved from 1.25760 to 1.20608, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - CER: 1.2297 - WER: 1.0000 - loss: 16.3580 - val_CER: 1.2061 - val_WER: 1.0000 - val_loss: 16.4057 - learning_rate: 0.0010
# Epoch 6/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - CER: 1.1888 - WER: 1.0000 - loss: 16.3342
# Epoch 6: val_CER improved from 1.20608 to 1.17173, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - CER: 1.1879 - WER: 1.0000 - loss: 16.3332 - val_CER: 1.1717 - val_WER: 1.0000 - val_loss: 16.4062 - learning_rate: 0.0010
# Epoch 7/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.1590 - WER: 1.0000 - loss: 16.2982
# Epoch 7: val_CER improved from 1.17173 to 1.14720, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - CER: 1.1584 - WER: 1.0000 - loss: 16.2987 - val_CER: 1.1472 - val_WER: 1.0000 - val_loss: 16.4003 - learning_rate: 0.0010
# Epoch 8/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.1379 - WER: 1.0000 - loss: 16.3056
# Epoch 8: val_CER improved from 1.14720 to 1.12880, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - CER: 1.1374 - WER: 1.0000 - loss: 16.3066 - val_CER: 1.1288 - val_WER: 1.0000 - val_loss: 16.3968 - learning_rate: 0.0010
# Epoch 9/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.1216 - WER: 1.0000 - loss: 16.3167
# Epoch 9: val_CER improved from 1.12880 to 1.11449, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - CER: 1.1212 - WER: 1.0000 - loss: 16.3164 - val_CER: 1.1145 - val_WER: 1.0000 - val_loss: 16.4016 - learning_rate: 0.0010
# Epoch 10/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - CER: 1.1087 - WER: 1.0000 - loss: 16.2911
# Epoch 10: val_CER improved from 1.11449 to 1.10304, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - CER: 1.1084 - WER: 1.0000 - loss: 16.2911 - val_CER: 1.1030 - val_WER: 1.0000 - val_loss: 16.4086 - learning_rate: 0.0010
# Epoch 11/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - CER: 1.0983 - WER: 1.0000 - loss: 16.3112
# Epoch 11: val_CER improved from 1.10304 to 1.09367, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - CER: 1.0981 - WER: 1.0000 - loss: 16.3110 - val_CER: 1.0937 - val_WER: 1.0000 - val_loss: 16.4119 - learning_rate: 0.0010
# Epoch 12/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - CER: 1.0898 - WER: 1.0000 - loss: 16.2824
# Epoch 12: val_CER improved from 1.09367 to 1.08587, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - CER: 1.0896 - WER: 1.0000 - loss: 16.2829 - val_CER: 1.0859 - val_WER: 1.0000 - val_loss: 16.4038 - learning_rate: 0.0010
# Epoch 13/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0826 - WER: 1.0000 - loss: 16.3069
# Epoch 13: val_CER improved from 1.08587 to 1.07926, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - CER: 1.0825 - WER: 1.0000 - loss: 16.3060 - val_CER: 1.0793 - val_WER: 1.0000 - val_loss: 16.4040 - learning_rate: 0.0010
# Epoch 14/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - CER: 1.0764 - WER: 1.0000 - loss: 16.3233
# Epoch 14: val_CER improved from 1.07926 to 1.07360, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - CER: 1.0763 - WER: 1.0000 - loss: 16.3220 - val_CER: 1.0736 - val_WER: 1.0000 - val_loss: 16.4094 - learning_rate: 0.0010
# Epoch 15/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.0711 - WER: 1.0000 - loss: 16.2997
# Epoch 15: val_CER improved from 1.07360 to 1.06869, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - CER: 1.0710 - WER: 1.0000 - loss: 16.2993 - val_CER: 1.0687 - val_WER: 1.0000 - val_loss: 16.3983 - learning_rate: 0.0010
# Epoch 16/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - CER: 1.0666 - WER: 1.0000 - loss: 16.2835
# Epoch 16: val_CER improved from 1.06869 to 1.06440, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - CER: 1.0665 - WER: 1.0000 - loss: 16.2839 - val_CER: 1.0644 - val_WER: 1.0000 - val_loss: 16.4098 - learning_rate: 0.0010
# Epoch 17/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - CER: 1.0625 - WER: 1.0000 - loss: 16.2668
# Epoch 17: val_CER improved from 1.06440 to 1.06061, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - CER: 1.0624 - WER: 1.0000 - loss: 16.2678 - val_CER: 1.0606 - val_WER: 1.0000 - val_loss: 16.3974 - learning_rate: 0.0010
# Epoch 18/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - CER: 1.0589 - WER: 1.0000 - loss: 16.2927
# Epoch 18: val_CER improved from 1.06061 to 1.05724, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - CER: 1.0589 - WER: 1.0000 - loss: 16.2923 - val_CER: 1.0572 - val_WER: 1.0000 - val_loss: 16.3857 - learning_rate: 0.0010
# Epoch 19/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.0557 - WER: 1.0000 - loss: 16.2869
# Epoch 19: val_CER improved from 1.05724 to 1.05423, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - CER: 1.0557 - WER: 1.0000 - loss: 16.2868 - val_CER: 1.0542 - val_WER: 1.0000 - val_loss: 16.4027 - learning_rate: 0.0010
# Epoch 20/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - CER: 1.0529 - WER: 1.0000 - loss: 16.2678
# Epoch 20: val_CER improved from 1.05423 to 1.05152, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - CER: 1.0529 - WER: 1.0000 - loss: 16.2685 - val_CER: 1.0515 - val_WER: 1.0000 - val_loss: 16.3940 - learning_rate: 0.0010
# Epoch 21/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - CER: 1.0503 - WER: 1.0000 - loss: 16.2795
# Epoch 21: val_CER improved from 1.05152 to 1.04907, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - CER: 1.0503 - WER: 1.0000 - loss: 16.2798 - val_CER: 1.0491 - val_WER: 1.0000 - val_loss: 16.3844 - learning_rate: 0.0010
# Epoch 22/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - CER: 1.0480 - WER: 1.0000 - loss: 16.2852
# Epoch 22: val_CER improved from 1.04907 to 1.04684, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - CER: 1.0479 - WER: 1.0000 - loss: 16.2844 - val_CER: 1.0468 - val_WER: 1.0000 - val_loss: 16.3785 - learning_rate: 0.0010
# Epoch 23/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - CER: 1.0458 - WER: 1.0000 - loss: 16.2500
# Epoch 23: val_CER improved from 1.04684 to 1.04480, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - CER: 1.0458 - WER: 1.0000 - loss: 16.2502 - val_CER: 1.0448 - val_WER: 1.0000 - val_loss: 16.3835 - learning_rate: 0.0010
# Epoch 24/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - CER: 1.0439 - WER: 1.0000 - loss: 16.2475
# Epoch 24: val_CER improved from 1.04480 to 1.04293, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - CER: 1.0438 - WER: 1.0000 - loss: 16.2474 - val_CER: 1.0429 - val_WER: 1.0000 - val_loss: 16.3664 - learning_rate: 0.0010
# Epoch 25/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.0421 - WER: 1.0000 - loss: 16.2178
# Epoch 25: val_CER improved from 1.04293 to 1.04122, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - CER: 1.0421 - WER: 1.0000 - loss: 16.2190 - val_CER: 1.0412 - val_WER: 1.0000 - val_loss: 16.3490 - learning_rate: 0.0010
# Epoch 26/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0404 - WER: 1.0000 - loss: 16.2275
# Epoch 26: val_CER improved from 1.04122 to 1.03963, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - CER: 1.0404 - WER: 1.0000 - loss: 16.2268 - val_CER: 1.0396 - val_WER: 1.0000 - val_loss: 16.3331 - learning_rate: 0.0010
# Epoch 27/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - CER: 1.0389 - WER: 1.0000 - loss: 16.2052
# Epoch 27: val_CER improved from 1.03963 to 1.03816, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - CER: 1.0389 - WER: 1.0000 - loss: 16.2067 - val_CER: 1.0382 - val_WER: 1.0000 - val_loss: 16.3221 - learning_rate: 0.0010
# Epoch 28/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - CER: 1.0375 - WER: 1.0000 - loss: 16.2029
# Epoch 28: val_CER improved from 1.03816 to 1.03680, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - CER: 1.0375 - WER: 1.0000 - loss: 16.2041 - val_CER: 1.0368 - val_WER: 1.0000 - val_loss: 16.3088 - learning_rate: 0.0010
# Epoch 29/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - CER: 1.0362 - WER: 1.0000 - loss: 16.1907
# Epoch 29: val_CER improved from 1.03680 to 1.03553, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - CER: 1.0362 - WER: 1.0000 - loss: 16.1908 - val_CER: 1.0355 - val_WER: 1.0000 - val_loss: 16.3017 - learning_rate: 0.0010
# Epoch 30/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - CER: 1.0350 - WER: 1.0000 - loss: 16.2056
# Epoch 30: val_CER improved from 1.03553 to 1.03435, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - CER: 1.0349 - WER: 1.0000 - loss: 16.2042 - val_CER: 1.0343 - val_WER: 1.0000 - val_loss: 16.2963 - learning_rate: 0.0010
# Epoch 31/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - CER: 1.0338 - WER: 1.0000 - loss: 16.1854
# Epoch 31: val_CER improved from 1.03435 to 1.03324, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - CER: 1.0338 - WER: 1.0000 - loss: 16.1828 - val_CER: 1.0332 - val_WER: 1.0000 - val_loss: 16.2794 - learning_rate: 0.0010
# Epoch 32/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - CER: 1.0327 - WER: 1.0000 - loss: 16.1369
# Epoch 32: val_CER improved from 1.03324 to 1.03220, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - CER: 1.0327 - WER: 1.0000 - loss: 16.1378 - val_CER: 1.0322 - val_WER: 1.0000 - val_loss: 16.2630 - learning_rate: 0.0010
# Epoch 33/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0317 - WER: 1.0000 - loss: 16.1148
# Epoch 33: val_CER improved from 1.03220 to 1.03122, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - CER: 1.0317 - WER: 1.0000 - loss: 16.1156 - val_CER: 1.0312 - val_WER: 1.0000 - val_loss: 16.2305 - learning_rate: 0.0010
# Epoch 34/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - CER: 1.0308 - WER: 1.0000 - loss: 16.1253
# Epoch 34: val_CER improved from 1.03122 to 1.03031, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - CER: 1.0308 - WER: 1.0000 - loss: 16.1252 - val_CER: 1.0303 - val_WER: 1.0000 - val_loss: 16.2324 - learning_rate: 0.0010
# Epoch 35/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - CER: 1.0299 - WER: 1.0000 - loss: 16.1534
# Epoch 35: val_CER improved from 1.03031 to 1.02944, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - CER: 1.0299 - WER: 1.0000 - loss: 16.1507 - val_CER: 1.0294 - val_WER: 1.0000 - val_loss: 16.2197 - learning_rate: 0.0010
# Epoch 36/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - CER: 1.0290 - WER: 1.0000 - loss: 16.1004
# Epoch 36: val_CER improved from 1.02944 to 1.02862, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - CER: 1.0290 - WER: 1.0000 - loss: 16.1008 - val_CER: 1.0286 - val_WER: 1.0000 - val_loss: 16.2092 - learning_rate: 0.0010
# Epoch 37/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0282 - WER: 1.0000 - loss: 16.1068
# Epoch 37: val_CER improved from 1.02862 to 1.02785, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - CER: 1.0282 - WER: 1.0000 - loss: 16.1046 - val_CER: 1.0278 - val_WER: 1.0000 - val_loss: 16.1941 - learning_rate: 0.0010
# Epoch 38/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - CER: 1.0275 - WER: 1.0000 - loss: 16.1132
# Epoch 38: val_CER improved from 1.02785 to 1.02709, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - CER: 1.0275 - WER: 1.0000 - loss: 16.1103 - val_CER: 1.0271 - val_WER: 1.0000 - val_loss: 16.1743 - learning_rate: 0.0010
# Epoch 39/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0267 - WER: 1.0000 - loss: 16.0645
# Epoch 39: val_CER improved from 1.02709 to 1.02628, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - CER: 1.0267 - WER: 1.0000 - loss: 16.0633 - val_CER: 1.0263 - val_WER: 1.0000 - val_loss: 16.1636 - learning_rate: 0.0010
# Epoch 40/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0258 - WER: 1.0000 - loss: 15.9881
# Epoch 40: val_CER improved from 1.02628 to 1.02526, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - CER: 1.0257 - WER: 1.0000 - loss: 15.9897 - val_CER: 1.0253 - val_WER: 1.0000 - val_loss: 16.1296 - learning_rate: 0.0010
# Epoch 41/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - CER: 1.0248 - WER: 1.0000 - loss: 15.9482
# Epoch 41: val_CER improved from 1.02526 to 1.02428, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - CER: 1.0247 - WER: 1.0000 - loss: 15.9508 - val_CER: 1.0243 - val_WER: 1.0000 - val_loss: 16.0625 - learning_rate: 0.0010
# Epoch 42/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - CER: 1.0236 - WER: 1.0000 - loss: 15.9800
# Epoch 42: val_CER improved from 1.02428 to 1.02298, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - CER: 1.0236 - WER: 1.0000 - loss: 15.9786 - val_CER: 1.0230 - val_WER: 1.0000 - val_loss: 16.1274 - learning_rate: 0.0010
# Epoch 43/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - CER: 1.0223 - WER: 1.0000 - loss: 15.9750
# Epoch 43: val_CER improved from 1.02298 to 1.02139, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - CER: 1.0222 - WER: 1.0000 - loss: 15.9718 - val_CER: 1.0214 - val_WER: 1.0000 - val_loss: 16.2484 - learning_rate: 0.0010
# Epoch 44/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - CER: 1.0205 - WER: 1.0000 - loss: 15.8614
# Epoch 44: val_CER improved from 1.02139 to 1.01945, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - CER: 1.0204 - WER: 1.0000 - loss: 15.8604 - val_CER: 1.0195 - val_WER: 1.0000 - val_loss: 16.2732 - learning_rate: 0.0010
# Epoch 45/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - CER: 1.0186 - WER: 1.0000 - loss: 15.8111
# Epoch 45: val_CER improved from 1.01945 to 1.01763, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - CER: 1.0185 - WER: 1.0000 - loss: 15.8115 - val_CER: 1.0176 - val_WER: 1.0000 - val_loss: 16.1061 - learning_rate: 0.0010
# Epoch 46/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.0168 - WER: 1.0000 - loss: 15.8534
# Epoch 46: val_CER improved from 1.01763 to 1.01582, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - CER: 1.0167 - WER: 1.0000 - loss: 15.8507 - val_CER: 1.0158 - val_WER: 1.0000 - val_loss: 16.2617 - learning_rate: 0.0010
# Epoch 47/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - CER: 1.0149 - WER: 1.0000 - loss: 15.7225
# Epoch 47: val_CER improved from 1.01582 to 1.01388, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 211ms/step - CER: 1.0148 - WER: 1.0000 - loss: 15.7238 - val_CER: 1.0139 - val_WER: 1.0000 - val_loss: 16.4946 - learning_rate: 0.0010
# Epoch 48/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - CER: 1.0130 - WER: 1.0000 - loss: 15.6859
# Epoch 48: val_CER improved from 1.01388 to 1.01201, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - CER: 1.0129 - WER: 1.0000 - loss: 15.6860 - val_CER: 1.0120 - val_WER: 1.0000 - val_loss: 16.1592 - learning_rate: 0.0010
# Epoch 49/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 1.0111 - WER: 1.0000 - loss: 15.6418
# Epoch 49: val_CER improved from 1.01201 to 1.01007, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - CER: 1.0110 - WER: 1.0000 - loss: 15.6387 - val_CER: 1.0101 - val_WER: 1.0000 - val_loss: 16.5331 - learning_rate: 0.0010
# Epoch 50/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - CER: 1.0091 - WER: 1.0000 - loss: 15.5693
# Epoch 50: val_CER improved from 1.01007 to 1.00805, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - CER: 1.0090 - WER: 1.0000 - loss: 15.5680 - val_CER: 1.0080 - val_WER: 1.0000 - val_loss: 16.1443 - learning_rate: 0.0010
# Epoch 51/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - CER: 1.0071 - WER: 1.0000 - loss: 15.3586
# Epoch 51: val_CER improved from 1.00805 to 1.00606, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - CER: 1.0070 - WER: 1.0000 - loss: 15.3612 - val_CER: 1.0061 - val_WER: 1.0000 - val_loss: 16.4469 - learning_rate: 0.0010
# Epoch 52/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - CER: 1.0051 - WER: 1.0000 - loss: 15.3510
# Epoch 52: val_CER improved from 1.00606 to 1.00402, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - CER: 1.0050 - WER: 1.0000 - loss: 15.3493 - val_CER: 1.0040 - val_WER: 1.0000 - val_loss: 16.0209 - learning_rate: 0.0010
# Epoch 53/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - CER: 1.0031 - WER: 1.0000 - loss: 15.2381
# Epoch 53: val_CER improved from 1.00402 to 1.00202, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - CER: 1.0030 - WER: 1.0000 - loss: 15.2393 - val_CER: 1.0020 - val_WER: 1.0000 - val_loss: 15.4307 - learning_rate: 0.0010
# Epoch 54/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - CER: 1.0010 - WER: 1.0000 - loss: 15.0845
# Epoch 54: val_CER improved from 1.00202 to 1.00001, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - CER: 1.0010 - WER: 1.0000 - loss: 15.0861 - val_CER: 1.0000 - val_WER: 1.0000 - val_loss: 15.8971 - learning_rate: 0.0010
# Epoch 55/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - CER: 0.9991 - WER: 1.0000 - loss: 15.0536
# Epoch 55: val_CER improved from 1.00001 to 0.99818, saving model to Models/02_captcha_to_text/202409291200/model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - CER: 0.1249 - WER: 0.2198 - loss: 0.0436 - val_CER: 0.1248 - val_WER: 0.2197 - val_loss: 0.3278 - learning_rate: 0.0010
# Epoch 895/1000
# 10/15 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - CER: 0.1248 - WER: 0.2196 - loss: 0.0451

# %%
import cv2
import typing
import numpy as np
from tensorflow.keras.models import load_model
from mltu.utils.text_utils import ctc_decoder, get_cer

class ImageToWordModel:
    def __init__(self, model_path: str, char_list: typing.Union[str, list]):
        self.model = load_model(model_path)  # Load the Keras model
        self.char_list = char_list
        self.input_shape = self.model.input_shape[1:3]  # Get input shape without batch size

    def predict(self, image: np.ndarray):
        # Resize the image to match the model's expected input shape
        image = cv2.resize(image, self.input_shape[::-1])  # Resize to (width, height)

        # Preprocess the image: Add batch dimension and convert to float32
        image_pred = np.expand_dims(image, axis=0).astype(np.float32)

        # Get predictions from the model
        preds = self.model.predict(image_pred)  # Get predictions

        # Decode predictions to text
        text = ctc_decoder(preds, self.char_list)[0]

        return text

if __name__ == "__main__":
    import pandas as pd
    from tqdm import tqdm
    from mltu.configs import BaseModelConfigs

    # Load configurations for the model
    configs = BaseModelConfigs.load("Models/02_captcha_to_text/202409291006/configs.yaml")

    # Initialize the model
    model = ImageToWordModel(model_path="/content/model.keras", char_list=configs.vocab)

    # Load validation data
    df = pd.read_csv("/content/Models/02_captcha_to_text/202409291006/val.csv").values.tolist()

    # Initialize a list to store Character Error Rates (CER)
    accum_cer = []

    # Iterate over the validation dataset
    for image_path, label in tqdm(df):
        image = cv2.imread(image_path.replace("\\", "/"))  # Load the image

        # Get prediction from the model
        prediction_text = model.predict(image)

        # Calculate CER
        cer = get_cer(prediction_text, label)
        print(f"Image: {image_path}, Label: {label}, Prediction: {prediction_text}, CER: {cer}")

        # Append CER to the list
        accum_cer.append(cer)

    # Print average CER
    print(f"Average CER: {np.average(accum_cer)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-eb2b69e10e4f> in <cell line: 28>()
#      35
#      36     # Initialize the model
# ---> 37     model = ImageToWordModel(model_path="/content/model.keras", char_list=configs.vocab)
#      38
#      39     # Load validation data
#
# <ipython-input-27-eb2b69e10e4f> in __init__(self, model_path, char_list)
#       7 class ImageToWordModel:
#       8     def __init__(self, model_path: str, char_list: typing.Union[str, list]):
# ----> 9         self.model = load_model(model_path)  # Load the Keras model
#      10         self.char_list = char_list
#      11         self.input_shape = self.model.input_shape[1:3]  # Get input shape without batch size
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     180
#     181     if is_keras_zip or is_keras_dir:
# --> 182         return saving_lib.load_model(
#     183             filepath,
#     184             custom_objects=custom_objects,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in load_model(filepath, custom_objects, compile, safe_mode)
#     235             )
#     236         with open(filepath, "rb") as f:
# --> 237             return _load_model_from_fileobj(
#     238                 f, custom_objects, compile, safe_mode
#     239             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     312             config_json = f.read()
#     313
# --> 314         model = _model_from_config(
#     315             config_json, custom_objects, compile, safe_mode
#     316         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     301     # Construct the model from the configuration file in the archive.
#     302     with ObjectSharingScope():
# --> 303         model = deserialize_keras_object(
#     304             config_dict, custom_objects, safe_mode=safe_mode
#     305         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     716     with custom_obj_scope, safe_mode_scope:
#     717         try:
# --> 718             instance = cls.from_config(inner_config)
#     719         except TypeError as e:
#     720             raise TypeError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/model.py in from_config(cls, config, custom_objects)
#     519             from keras.src.models.functional import functional_from_config
#     520
# --> 521             return functional_from_config(
#     522                 cls, config, custom_objects=custom_objects
#     523             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in functional_from_config(cls, config, custom_objects)
#     475     # First, we create all layers and enqueue nodes to be processed
#     476     for layer_data in config["layers"]:
# --> 477         process_layer(layer_data)
#     478
#     479     # Then we process nodes in order of layer depth.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in process_layer(layer_data)
#     459             )
#     460         else:
# --> 461             layer = serialization_lib.deserialize_keras_object(
#     462                 layer_data, custom_objects=custom_objects
#     463             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     716     with custom_obj_scope, safe_mode_scope:
#     717         try:
# --> 718             instance = cls.from_config(inner_config)
#     719         except TypeError as e:
#     720             raise TypeError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/lambda_layer.py in from_config(cls, config, custom_objects, safe_mode)
#     188             and fn_config["class_name"] == "__lambda__"
#     189         ):
# --> 190             cls._raise_for_lambda_deserialization("function", safe_mode)
#     191             inner_config = fn_config["config"]
#     192             fn = python_utils.func_load(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/lambda_layer.py in _raise_for_lambda_deserialization(arg_name, safe_mode)
#     170     def _raise_for_lambda_deserialization(arg_name, safe_mode):
#     171         if safe_mode:
# --> 172             raise ValueError(
#     173                 "The `{arg_name}` of this `Lambda` layer is a Python lambda. "
#     174                 "Deserializing it is unsafe. If you trust the source of the "
#
# ValueError: The `{arg_name}` of this `Lambda` layer is a Python lambda. Deserializing it is unsafe. If you trust the source of the config artifact, you can override this error by passing `safe_mode=False` to `from_config()`, or calling `keras.config.enable_unsafe_deserialization().

# %%
# !pip install tf2onnx
# !pip install mltu
# !pip install keras
# Out:
# Collecting tf2onnx
#   Downloading tf2onnx-1.16.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.26.4)
# Collecting onnx>=1.4.1 (from tf2onnx)
#   Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (24.3.25)
# Requirement already satisfied: protobuf~=3.20 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2024.8.30)
# Downloading tf2onnx-1.16.1-py3-none-any.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 13.3 MB/s eta 0:00:00
# Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 69.3 MB/s eta 0:00:00
# Installing collected packages: onnx, tf2onnx
# Successfully installed onnx-1.16.2 tf2onnx-1.16.1
# Collecting mltu
#   Downloading mltu-1.2.5-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mltu) (4.66.5)
# Collecting qqdm==0.0.7 (from mltu)
#   Downloading qqdm-0.0.7.tar.gz (5.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mltu) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mltu) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from mltu) (4.10.0.84)
# Requirement already satisfied: Pillow>=9.4.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (10.4.0)
# Collecting onnxruntime>=1.15.0 (from mltu)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mltu) (3.7.1)
# Collecting addict (from qqdm==0.0.7->mltu)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting jupyter (from qqdm==0.0.7->mltu)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting coloredlogs (from onnxruntime>=1.15.0->mltu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (24.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (1.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mltu) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mltu) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mltu) (1.16.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.15.0->mltu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (6.5.5)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (7.7.1)
# Collecting jupyterlab (from jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.15.0->mltu) (1.3.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (6.3.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->qqdm==0.0.7->mltu) (3.6.9)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->qqdm==0.0.7->mltu) (3.0.13)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->qqdm==0.0.7->mltu) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->qqdm==0.0.7->mltu) (2.18.0)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting ipykernel (from jupyter->qqdm==0.0.7->mltu)
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.1.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (5.7.2)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (71.0.4)
# Requirement already satisfied: tomli>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.0.1)
# Collecting comm>=0.1.1 (from ipykernel->jupyter->qqdm==0.0.7->mltu)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (1.6.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (24.0.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.10.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (1.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (23.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru>=1.0.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (4.12.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->jupyter->qqdm==0.0.7->mltu)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->qqdm==0.0.7->mltu) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->qqdm==0.0.7->mltu) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->jupyterlab->jupyter->qqdm==0.0.7->mltu) (4.3.6)
# Collecting jupyter-client (from jupyter-console->jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->qqdm==0.0.7->mltu) (21.2.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.16.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->qqdm==0.0.7->mltu) (2.20.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->qqdm==0.0.7->mltu) (0.2.13)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->jupyter->qqdm==0.0.7->mltu) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->qqdm==0.0.7->mltu) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter->qqdm==0.0.7->mltu) (0.5.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.20.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->qqdm==0.0.7->mltu) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->qqdm==0.0.7->mltu) (2.22)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (24.8.0)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu)
#   Downloading types_python_dateutil-2.9.0.20240906-py3-none-any.whl.metadata (1.9 kB)
# Downloading mltu-1.2.5-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.2 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 110.5 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.8 MB/s eta 0:00:00
# Downloading jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 116.0 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 10.2 MB/s eta 0:00:00
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.7 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 7.1 MB/s eta 0:00:00
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 26.1 MB/s eta 0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 12.9 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.5 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading json5-0.9.25-py3-none-any.whl (30 kB)
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.4 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20240906-py3-none-any.whl (9.7 kB)
# Building wheels for collected packages: qqdm
#   Building wheel for qqdm (setup.py) ... done
#   Created wheel for qqdm: filename=qqdm-0.0.7-py3-none-any.whl size=6466 sha256=4c316613e8c50fd08a2076a8dbd45c4ab7cf94c7104a0b33466d9f6b47954c35
#   Stored in directory: /root/.cache/pip/wheels/40/1a/56/5dccdea123a172661eb65c8c29fde4567dbda2b72b5fc5893a
# Successfully built qqdm
# Installing collected packages: addict, uri-template, types-python-dateutil, rfc3986-validator, rfc3339-validator, python-json-logger, overrides, jsonpointer, json5, jedi, humanfriendly, h11, fqdn, comm, async-lru, jupyter-server-terminals, jupyter-client, httpcore, coloredlogs, arrow, onnxruntime, isoduration, ipykernel, httpx, jupyter-events, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, qqdm, mltu
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.29.5 which is incompatible.
# Successfully installed addict-2.4.0 arrow-1.3.0 async-lru-2.0.4 coloredlogs-15.0.1 comm-0.2.2 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 humanfriendly-10.0 ipykernel-6.29.5 isoduration-20.11.0 jedi-0.19.1 json5-0.9.25 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-client-7.4.9 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-server-2.27.3 mltu-1.2.5 onnxruntime-1.19.2 overrides-7.7.0 python-json-logger-2.0.7 qqdm-0.0.7 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 types-python-dateutil-2.9.0.20240906 uri-template-1.3.0
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import tensorflow as tf
from keras.models import load_model

# Enable unsafe deserialization
tf.keras.backend.clear_session()  # Optional: Clears the current Keras session
tf.keras.config.enable_unsafe_deserialization()

# Load the model
model = load_model("model.keras")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     717         try:
# --> 718             instance = cls.from_config(inner_config)
#     719         except TypeError as e:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses/loss.py in from_config(cls, config)
#      70     def from_config(cls, config):
# ---> 71         return cls(**config)
#      72
#
# TypeError: CTCloss.__init__() got an unexpected keyword argument 'reduction'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0480397b7c32> in <cell line: 9>()
#       7
#       8 # Load the model
# ----> 9 model = load_model("model.keras")
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     180
#     181     if is_keras_zip or is_keras_dir:
# --> 182         return saving_lib.load_model(
#     183             filepath,
#     184             custom_objects=custom_objects,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in load_model(filepath, custom_objects, compile, safe_mode)
#     235             )
#     236         with open(filepath, "rb") as f:
# --> 237             return _load_model_from_fileobj(
#     238                 f, custom_objects, compile, safe_mode
#     239             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     312             config_json = f.read()
#     313
# --> 314         model = _model_from_config(
#     315             config_json, custom_objects, compile, safe_mode
#     316         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     301     # Construct the model from the configuration file in the archive.
#     302     with ObjectSharingScope():
# --> 303         model = deserialize_keras_object(
#     304             config_dict, custom_objects, safe_mode=safe_mode
#     305         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732         compile_config = config.get("compile_config", None)
#     733         if compile_config:
# --> 734             instance.compile_from_config(compile_config)
#     735             instance.compiled = True
#     736
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/trainer.py in compile_from_config(self, config)
#     900             )
#     901             return
# --> 902         config = serialization_lib.deserialize_keras_object(config)
#     903         self.compile(**config)
#     904         if hasattr(self, "optimizer") and self.built:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     592
#     593     if "class_name" not in config or "config" not in config:
# --> 594         return {
#     595             key: deserialize_keras_object(
#     596                 value, custom_objects=custom_objects, safe_mode=safe_mode
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in <dictcomp>(.0)
#     593     if "class_name" not in config or "config" not in config:
#     594         return {
# --> 595             key: deserialize_keras_object(
#     596                 value, custom_objects=custom_objects, safe_mode=safe_mode
#     597             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     718             instance = cls.from_config(inner_config)
#     719         except TypeError as e:
# --> 720             raise TypeError(
#     721                 f"{cls} could not be deserialized properly. Please"
#     722                 " ensure that components that are Python object"
#
# TypeError: <class 'mltu.tensorflow.losses.CTCloss'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'mltu.tensorflow.losses', 'class_name': 'CTCloss', 'config': {'name': 'CTCloss', 'reduction': 'sum_over_batch_size'}, 'registered_name': 'CTCloss'}.
#
# Exception encountered: CTCloss.__init__() got an unexpected keyword argument 'reduction'

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
